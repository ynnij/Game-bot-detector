# %%
#모든 데이터 사용
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import sklearn.metrics as mt

action_data =pd.read_csv('Player actions features.csv')

data = action_data[['collect_max_count','Sit_ratio','Sit_count','sit_count_per_day','Exp_get_ratio',
                    'Exp_get_count','exp_get_count_per_day','Item_get_ratio','Item_get_count','item_get_count_per_day',
                    'Money_get_ratio','Money_get_count','money_get_count_per_day','Abyss_get_ratio',
                    'Abyss_get_count','abyss_get_count_per_day','Exp_repair_count','Exp_repair_count_per_day',
                   'Use_portal_count','Use_portal_count_per_day','Killed_bypc_count','Killed_bypc_count_per_day',
                   'Killed_bynpc_count','Killed_bynpc_count_per_day','Teleport_count','Teleport_count_per_day',
                   'Reborn_count','Reborn_count_per_day']]

Type1 = []

for each in action_data['Type']:
    if each == 'Human':
        Type1.append(1)
    else:
        Type1.append(0)
        
action_data['Type'] = Type1

target = action_data['Type']
X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size=0.3, random_state=0)



clf = GaussianNB()

clf.fit(X_train, Y_train)

from sklearn.model_selection import cross_val_score, cross_validate

scores = cross_val_score(clf, X_train, Y_train, cv=5)

print('cross validation avg: ', scores.mean())

pred = clf.predict(X_test)    

accuracy = mt.accuracy_score(Y_test, pred)
recall = mt.recall_score(Y_test, pred)
precision = mt.precision_score(Y_test, pred)
f1_score = mt.f1_score(Y_test, pred)

print('Accuracy: ', format(accuracy))
print('Recall: ', format(recall))
print('Precision: ', format(precision))
print('F1_score: ', format(f1_score))

#탐지 결과 출력
print("------ Result------")
i = 1
hn =0
bn =0
total =0
for each in pred :
    if each == 1:
        hn +=1
        print("NO.%d is Human." %(i))
    else:
        bn+=1
        print("NO.%d is Bot." %(i))
    i+=1
    total +=1
print('human number :',hn)
print('Bot number : ',bn)
print('total : ',total)
# Out:
# cross validation avg:  0.9350030476178219
# Accuracy:  0.9328508242862887
# Recall:  0.9690547492897182
# Precision:  0.9546864361903321
# F1_score:  0.9618169346848563
# ------ Result------
# human number : 13219
# Bot number :  1703
# total :  14922

# %%
#상위 4개 데이터만 사용 
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import sklearn.metrics as mt

action_data =pd.read_csv('Player actions features.csv')

data = action_data[['item_get_count_per_day','exp_get_count_per_day','Exp_get_ratio','Item_get_ratio']]

Type1 = []

for each in action_data['Type']:
    if each == 'Human':
        Type1.append(1)
    else:
        Type1.append(0)
        
action_data['Type'] = Type1

target = action_data['Type']
X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size=0.3, random_state=0)



clf = GaussianNB()

clf.fit(X_train, Y_train)

from sklearn.model_selection import cross_val_score, cross_validate

scores = cross_val_score(clf, X_train, Y_train, cv=5)

print('cross validation avg: ', scores.mean())

pred = clf.predict(X_test)    

accuracy = mt.accuracy_score(Y_test, pred)
recall = mt.recall_score(Y_test, pred)
precision = mt.precision_score(Y_test, pred)
f1_score = mt.f1_score(Y_test, pred)

print('Accuracy: ', format(accuracy))
print('Recall: ', format(recall))
print('Precision: ', format(precision))
print('F1_score: ', format(f1_score))

#탐지 결과 출력
print("------ Result------")
i = 1
hn =0
bn =0
total =0
for each in pred :
    if each == 1:
        hn +=1
        #print("NO.%d is Human." %(i))
    else:
        bn+=1
        #print("NO.%d is Bot." %(i))
    i+=1
    total +=1
print('human number :',hn)
print('Bot number : ',bn)
print('total : ',total)
# Out:
# cross validation avg:  0.9435907759922122
# Accuracy:  0.9404235357190726
# Recall:  0.9765798971051217
# Precision:  0.9560968275447301
# F1_score:  0.9662298195631529
# ------ Result------
# human number : 13302
# Bot number :  1620
# total :  14922

# %%
#하위 4개 데이터만 사용 
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import sklearn.metrics as mt

action_data =pd.read_csv('Player actions features.csv')

data = action_data[['collect_max_count','money_get_count_per_day','Sit_count', 'Sit_ratio']]

Type1 = []

for each in action_data['Type']:
    if each == 'Human':
        Type1.append(1)
    else:
        Type1.append(0)
        
action_data['Type'] = Type1

target = action_data['Type']
X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size=0.3, random_state=0)



clf = GaussianNB()

clf.fit(X_train, Y_train)

from sklearn.model_selection import cross_val_score, cross_validate

scores = cross_val_score(clf, X_train, Y_train, cv=5)

print('cross validation avg: ', scores.mean())

pred = clf.predict(X_test)    

accuracy = mt.accuracy_score(Y_test, pred)
recall = mt.recall_score(Y_test, pred)
precision = mt.precision_score(Y_test, pred)
f1_score = mt.f1_score(Y_test, pred)

print('Accuracy: ', format(accuracy))
print('Recall: ', format(recall))
print('Precision: ', format(precision))
print('F1_score: ', format(f1_score))

#탐지 결과 출력
print("------ Result------")
i = 1
hn =0
bn =0
total =0
for each in pred :
    if each == 1:
        hn +=1
        #print("NO.%d is Human." %(i))
    else:
        bn+=1
        #print("NO.%d is Bot." %(i))
    i+=1
    total +=1
print('human number :',hn)
print('Bot number : ',bn)
print('total : ',total)
# Out:
# cross validation avg:  0.9254961875699264
# Accuracy:  0.9254791582897735
# Recall:  0.980112109345005
# Precision:  0.9373577146214291
# F1_score:  0.9582582582582583
# ------ Result------
# human number : 13617
# Bot number :  1305
# total :  14922
